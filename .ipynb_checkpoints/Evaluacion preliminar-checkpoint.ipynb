# %% [markdown]
# # **Dataset: NASA Exoplanet Archive (DOI 10.26133/NEA4)**

# %%
# !pip install pandas --upgrade  --quiet
# !pip install numpy --upgrade  --quiet
# !pip install scipy --upgrade  --quiet
# !pip install statsmodels --upgrade  --quiet
# !pip install scikit-learn --upgrade  --quiet
# !pip install missingno --upgrade  --quiet

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.impute import SimpleImputer

# %%
# IMPORTAR DATASET
exo = pd.read_csv('exoplanets.csv')
print("Dataset cargado exitosamente.")
print("Dimensiones:", exo.shape)
# Out:
# Dataset cargado exitosamente.
# Dimensiones: (9564, 49)

# %% [markdown]
# Contenido:
# 1. Descripción del conjunto de datos y su fuente
# 2. Visualización de las variables comparándolas con el objetivo
# 3. Matriz de correlación de las variables
# 4. Resultados de referencia con un modelo simple (regresión lineal) aplicando un preproceso de los datos

# %% [markdown]
# ## 1. Descripción del conjunto de datos y su fuente
# Los datos fueron medidos por la misión Kepler (telescopio espacial de la NASA).
#
# El objetivo es entrenar un modelo capaz de predecir si una observación es un candidato real a ser un exoplaneta o no. Por tanto, este es un problema de classificación, donde la variable objetivo es koi_disposition; es decir, decidir a que categoria perteneze cada entrada: CANDIDATE, FALSE POSITIVE, NOT DISPOSITIONED o CONFIRMED.
#
# En cuanto al dataset seleccionado, se pueden comentar brevemente los siguientes problemas:
# 1. Contiene atributos relacionados con el tiempo. Algunas columnas (koi_time0bk, koi_time0, etc.) reflejan mediciones temporales o fases de observación, por lo que pueden ser altamente correlacionadas entre sí o con errores (_err1, _err2).
# 2. Hay un desbalance entre clases. La variable objetivo koi_disposition tiene cuatro clases, y en el dataset suele haber muchos más candidatos que falsos positivos, y no hay casi elementos no dispuestos, generando desbalance de clases.
#
# A continuación vamos a explicar brevemente en que consiste cada variable:
# - **kepid:** Número de identificación Kepler (KepID). Identificador único del objetivo en el Kepler Input Catalog (KIC). Es un número entero de 9 dígitos.
# - **kepoi_name:** Nombre del Objeto de Interés Kepler (KOI). Identificador en formato KIC (con un '.01', '.02', ... al final para sistemas con múltiples candidatos).
# - **kepler_name:** Nombre del planeta confirmado por Kepler. Asignado por el equipo de Kepler a planetas confirmados/validados. Formato: 'Kepler-' + número + letra (ej: Kepler-11 b). Para candidatos no confirmados, el valor es 'NaN'.
# - **koi_disposition:** Disposición del KOI en el Exoplanet Archive. Categoría asignada basada en la evidencia disponible: CANDIDATE (señal consistente con planeta), FALSE POSITIVE (señal explicada por otros fenómenos), NOT DISPOSITIONED (análisis incompleto), o CONFIRMED (confirmado por métodos independientes).
# - **koi_pdisposition:** Disposición del KOI usando solo datos de Kepler. Representa la explicación física más probable antes de considerar observaciones de seguimiento. Puede diferir de koi_disposition cuando hay datos externos.
# - **koi_score:** Puntuación de disposición del KOI. Valor entre 0 y 1 que indica la confianza en que la señal sea planetaria, donde 1 es máxima confianza. Basado en un clasificador automático que evalúa múltiples características del tránsito.
# - **koi_fpflag_nt:** Indica si la curva de luz es inconsistente con un tránsito planetario. Valores: 1 (problemas de forma/fase), 0 (forma de tránsito aceptable)."
# - **koi_fpflag_ss:** Señala si el KOI probablemente corresponde a un sistema binario eclipsante.
# - **koi_fpflag_co:** Indica si la fuente de la señal está en una estrella cercana diferente al objetivo, basado en análisis de desplazamiento del centroide durante el tránsito.
# - **koi_fpflag_ec:** Detecta contaminación por coincidencia con tránsitos de otros KOIs conocidos en el mismo campo, sugiriendo contaminación cruzada.
# - **koi_period:** Periodo orbital en días. Tiempo entre tránsitos consecutivos medido por ajuste de modelo de tránsito a los datos de fotometría de Kepler.
# - **koi_period_err1:** Incertidumbre positiva (+1σ) en el periodo orbital, en días. Representa el percentil 84 de la distribución posterior del parámetro.
# - **koi_period_err2:** Incertidumbre negativa (-1σ) en el periodo orbital, en días. Representa el percentil 16 de la distribución posterior del parámetro.
# - **koi_time0bk:** Época de tránsito de referencia. Tiempo del centro del primer tránsito detectado, expresado en BKJD (Besselian Kepler Julian Date).
# - **koi_time0bk_err1:** Incertidumbre positiva (+1σ) en la época de tránsito, en días BKJD.
# - **koi_time0bk_err2:** Incertidumbre negativa (-1σ) en la época de tránsito, en días BKJD.
# - **koi_impact:** Parámetro de impacto. Distancia normalizada entre la proyección del planeta sobre el disco estelar y el centro de la estrella, en unidades de radios estelares. Rango: 0 (tránsito central) a 1 (tránsito tangencial).
# - **koi_impact_err1:** Incertidumbre positiva (+1σ) en el parámetro de impacto.
# - **koi_impact_err2:** Incertidumbre negativa (-1σ) en el parámetro de impacto.
# - **koi_duration:** Duración del tránsito en horas. Intervalo de tiempo desde el primer hasta el último contacto del tránsito, incluyendo los efectos de limb-darkening.
# - **koi_duration_err1:** Incertidumbre positiva (+1σ) en la duración del tránsito, en horas.
# - **koi_duration_err2:** Incertidumbre negativa (-1σ) en la duración del tránsito, en horas.
# - **koi_depth:** Profundidad del tránsito en partes por millón (ppm). Diferencia fraccional en flujo entre fuera del tránsito y el mínimo del tránsito: (F_out - F_in)/F_out × 10^6.
# - **koi_depth_err1:** Incertidumbre positiva (+1σ) en la profundidad del tránsito, en ppm.
# - **koi_depth_err2:** Incertidumbre negativa (-1σ) en la profundidad del tránsito, en ppm.
# - **koi_prad:** Radio planetario en radios terrestres. Radio físico del planeta derivado de la profundidad del tránsito y parámetros estelares. Rt = 6,371 km.
# - **koi_prad_err1:** Incertidumbre positiva (+1σ) en el radio planetario, en radios terrestres.
# - **koi_prad_err2:** Incertidumbre negativa (-1σ) en el radio planetario, en radios terrestres.
# - **koi_teq:** Temperatura de equilibrio del planeta en Kelvin. Temperatura que tendría el planeta asumiendo albedo Bond cero y redistribución de calor completa: T_eq = T_eff × √(R_star/2a).
# - **koi_teq_err1:** Incertidumbre positiva (+1σ) en la temperatura de equilibrio, en Kelvin.
# - **koi_teq_err2:** Incertidumbre negativa (-1σ) en la temperatura de equilibrio, en Kelvin.
# - **koi_insol:** Insolación planetaria en unidades terrestres. Flujo de radiación recibido por el planeta dividido por el flujo solar recibido por la Tierra en la parte superior de la atmósfera (1361 W/m²).
# - **koi_insol_err1:** Incertidumbre positiva (+1σ) en la insolación planetaria, en unidades terrestres.
# - **koi_insol_err2:** Incertidumbre negativa (-1σ) en la insolación planetaria, en unidades terrestres.
# - **koi_model_snr:** Relación señal-ruido del modelo de tránsito. SNR de la señal de tránsito calculada como la profundidad dividida por la incertidumbre en la profundidad, derivada del ajuste del modelo.
# - **koi_count:** Número de candidatos planetarios en el sistema. Cuenta total de KOIs asociados al mismo Kepid (sistema estelar), indicando la multiplicidad del sistema.
# - **koi_tce_plnt_num:** Número de planeta en el TCE. Identificador secuencial del planeta dentro del conjunto de Threshold Crossing Events federado al KOI.
# - **koi_tce_delivname:** Nombre de la entrega TCE. Identifica la versión específica del procesamiento de datos que produjo el Threshold Crossing Event federado al KOI."
# - **koi_steff:** Temperatura efectiva estelar en Kelvin. Temperatura de un cuerpo negro que emitiría la misma radiación total por unidad de área superficial que la estrella.
# - **koi_steff_err1:** Incertidumbre positiva (+1σ) en la temperatura efectiva estelar, en Kelvin.
# - **koi_steff_err2:** Incertidumbre negativa (-1σ) en la temperatura efectiva estelar, en Kelvin.
# - **koi_slogg:** Gravedad superficial estelar en log10(cm/s²). Logaritmo base 10 de la aceleración gravitacional en la superficie de la estrella.
# - **koi_slogg_err1:** Incertidumbre positiva (+1σ) en la gravedad superficial estelar, en log10(cm/s²).
# - **koi_slogg_err2:** Incertidumbre negativa (-1σ) en la gravedad superficial estelar, en log10(cm/s²).
# - **koi_srad:** Radio estelar en radios solares. Radio físico de la estrella derivado de modelos evolutivos estelares o relaciones escala. Rs = 696,342 km.
# - **koi_srad_err1:** Incertidumbre positiva (+1σ) en el radio estelar, en radios solares.
# - **koi_srad_err2:** Incertidumbre negativa (-1σ) en el radio estelar, en radios solares.
# - **ra:** Ascensión recta en grados. Coordenada ecuatorial celeste, análoga a la longitud terrestre. Rango: 0° a 360°.
# - **dec:** Declinación en grados. Coordenada ecuatorial celeste, análoga a la latitud terrestre. Rango: -90° a +90°.
# - **koi_kepmag:** Magnitud Kepler. Magnitud aparente de la estrella en la banda de paso del instrumento Kepler (aproximadamente 430-890 nm). Sistema fotométrico AB.

# %% [markdown]
# Mirando los datos importados, vemos que hay dos columnas cuyos valores valen todos 'NaN': koi_teq_err1 y koi_teq_err2. Las eliminamos de nuestros datos.

# %%
exo = exo.drop("koi_teq_err1", axis = 1)
exo = exo.drop("koi_teq_err2", axis = 1)

# %% [markdown]
# ## 2. Visualización de las variables comparándolas con el objetivo

# %%
col_numericas = exo.select_dtypes(include=['number']).columns # 42 columnas numericas
fig, axes = plt.subplots(21, 2, figsize = (20, 140))
axes = axes.ravel()
for i, col in enumerate(col_numericas):
    sns.boxplot(x = 'koi_disposition', y = col, data = exo, ax = axes[i])
    axes[i].set_title(f'{col} por koi_disposition')
plt.tight_layout()
plt.show()

# %%
sns.histplot(exo, x = "koi_score", hue = "koi_disposition")
# Out:
# <Axes: xlabel='koi_score', ylabel='Count'>

# %% [markdown]
# ## 3. Matriz de correlación de las variables numéricas

# %%
corr = exo[col_numericas].corr()
display(corr)
plt.figure(figsize=(12, 10))
sns.heatmap(corr, annot = False, fmt = ".2f", cmap = 'coolwarm', center = 0)
plt.title('Matriz de Correlación (Solo Variables Numéricas)')
plt.tight_layout()
plt.show()
# Out:
#                       kepid  koi_score  koi_fpflag_nt  koi_fpflag_ss  \
# kepid              1.000000   0.095225       0.008139      -0.048630
# koi_score          0.095225   1.000000      -0.006986      -0.556077
# koi_fpflag_nt      0.008139  -0.006986       1.000000      -0.023270
# koi_fpflag_ss     -0.048630  -0.556077      -0.023270       1.000000
# koi_fpflag_co     -0.098636  -0.510013      -0.004575       0.151233
# koi_fpflag_ec     -0.044213  -0.398247       0.000576       0.096539
# koi_period         0.011511  -0.070669       0.001554      -0.020557
# koi_period_err1    0.011620  -0.093041       0.021207      -0.136246
# koi_period_err2   -0.011620   0.093041      -0.021207       0.136246
# koi_time0bk        0.013620  -0.008329       0.016143      -0.117435
# koi_time0bk_err1  -0.002222  -0.028337       0.014174      -0.174347
# koi_time0bk_err2   0.002222   0.028337      -0.014174       0.174347
# koi_impact         0.000358  -0.214340       0.001844       0.042286
# koi_impact_err1   -0.032893  -0.121752      -0.003784       0.148209
# koi_impact_err2   -0.007212  -0.072176      -0.003361       0.050605
# koi_duration      -0.026407  -0.173200       0.015080       0.028321
# koi_duration_err1 -0.015497  -0.095304       0.020009      -0.183831
# koi_duration_err2  0.015497   0.095304      -0.020009       0.183831
# koi_depth         -0.017484  -0.301013      -0.005423       0.426253
# koi_depth_err1    -0.016191  -0.166532       0.001852       0.008412
# koi_depth_err2     0.016191   0.166532      -0.001852      -0.008412
# koi_prad           0.003681  -0.076870       0.002195       0.001396
# koi_prad_err1      0.006186  -0.054576       0.001563       0.006230
# koi_prad_err2     -0.003858   0.049572      -0.002261       0.001706
# koi_teq           -0.058705  -0.302279      -0.004703       0.204909
# koi_insol         -0.012403  -0.030995      -0.000075       0.039564
# koi_insol_err1    -0.010518  -0.043238       0.001463       0.035638
# koi_insol_err2     0.013167   0.026134      -0.000112      -0.036514
# koi_model_snr      0.000998  -0.269034      -0.007878       0.437881
# koi_tce_plnt_num   0.025220   0.209081      -0.003074      -0.182321
# koi_steff         -0.025494  -0.192544       0.001885       0.107830
# koi_steff_err1    -0.004420  -0.372432       0.017372       0.200990
# koi_steff_err2     0.003128   0.333595      -0.011204      -0.175995
# koi_slogg          0.052255   0.150017      -0.001982      -0.076140
# koi_slogg_err1    -0.026706  -0.164267      -0.001589       0.123719
# koi_slogg_err2    -0.024098   0.228382      -0.006561      -0.043734
# koi_srad          -0.027171  -0.071767       0.000393       0.047205
# koi_srad_err1     -0.027871  -0.117010       0.002640       0.051208
# koi_srad_err2      0.024720   0.075529      -0.001160      -0.045701
# ra                -0.002288  -0.168666       0.012693       0.086374
# dec                0.993587   0.094944       0.007914      -0.048116
# koi_kepmag         0.017525   0.042112      -0.003753       0.000628
#
#                    koi_fpflag_co  koi_fpflag_ec  koi_period  koi_period_err1  \
# kepid                  -0.098636      -0.044213    0.011511         0.011620
# koi_score              -0.510013      -0.398247   -0.070669        -0.093041
# koi_fpflag_nt          -0.004575       0.000576    0.001554         0.021207
# koi_fpflag_ss           0.151233       0.096539   -0.020557        -0.136246
# koi_fpflag_co           1.000000       0.523851   -0.020804        -0.092079
# koi_fpflag_ec           0.523851       1.000000   -0.017021        -0.082203
# koi_period             -0.020804      -0.017021    1.000000         0.053146
# koi_period_err1        -0.092079      -0.082203    0.053146         1.000000
# koi_period_err2         0.092079       0.082203   -0.053146        -1.000000
# koi_time0bk            -0.123592      -0.101114    0.095580         0.429869
# koi_time0bk_err1       -0.034860       0.001963    0.020776         0.515698
# koi_time0bk_err2        0.034860      -0.001963   -0.020776        -0.515698
# koi_impact              0.005343      -0.004968    0.004928         0.024984
# koi_impact_err1         0.114995       0.034609   -0.001884        -0.014050
# koi_impact_err2         0.001008       0.009899   -0.003843        -0.031717
# koi_duration           -0.046753       0.018982    0.037302         0.272678
# koi_duration_err1      -0.020958       0.016893    0.032922         0.543305
# koi_duration_err2       0.020958      -0.016893   -0.032922        -0.543305
# koi_depth              -0.125222      -0.086801   -0.009182        -0.071058
# koi_depth_err1         -0.010774      -0.003620    0.002661         0.007781
# koi_depth_err2          0.010774       0.003620   -0.002661        -0.007781
# koi_prad               -0.012231      -0.010145    0.005135         0.023327
# koi_prad_err1          -0.016944      -0.012600    0.003440         0.017064
# koi_prad_err2           0.011822       0.008867   -0.004966        -0.022526
# koi_teq                 0.268092       0.217612   -0.049097        -0.233077
# koi_insol               0.023024       0.030209   -0.002603        -0.011829
# koi_insol_err1          0.024604       0.038883   -0.003642        -0.016890
# koi_insol_err2         -0.015976      -0.024718    0.002448         0.011013
# koi_model_snr          -0.127536      -0.089809   -0.009614        -0.081277
# koi_tce_plnt_num       -0.132786      -0.095758   -0.015107         0.017752
# koi_steff               0.017717       0.011633   -0.013552         0.034960
# koi_steff_err1          0.149347       0.111744    0.005325         0.080747
# koi_steff_err2         -0.111859      -0.077747    0.003194        -0.058992
# koi_slogg              -0.018899       0.002046    0.001877        -0.006293
# koi_slogg_err1         -0.007460      -0.005278   -0.006466         0.005176
# koi_slogg_err2         -0.050906      -0.036580   -0.003180        -0.186627
# koi_srad                0.041572       0.019290   -0.000993         0.005859
# koi_srad_err1           0.038069       0.026828   -0.000435         0.032526
# koi_srad_err2          -0.030926      -0.010113    0.001556        -0.002350
# ra                      0.159923       0.070498    0.005670        -0.032093
# dec                    -0.097175      -0.045119    0.011479         0.009394
# koi_kepmag              0.060592       0.039075   -0.009858        -0.025988
#
#                    koi_period_err2  koi_time0bk  ...  koi_steff_err2  \
# kepid                    -0.011620     0.013620  ...        0.003128
# koi_score                 0.093041    -0.008329  ...        0.333595
# koi_fpflag_nt            -0.021207     0.016143  ...       -0.011204
# koi_fpflag_ss             0.136246    -0.117435  ...       -0.175995
# koi_fpflag_co             0.092079    -0.123592  ...       -0.111859
# koi_fpflag_ec             0.082203    -0.101114  ...       -0.077747
# koi_period               -0.053146     0.095580  ...        0.003194
# koi_period_err1          -1.000000     0.429869  ...       -0.058992
# koi_period_err2           1.000000    -0.429869  ...        0.058992
# koi_time0bk              -0.429869     1.000000  ...       -0.026393
# koi_time0bk_err1         -0.515698     0.165660  ...       -0.065439
# koi_time0bk_err2          0.515698    -0.165660  ...        0.065439
# koi_impact               -0.024984     0.049241  ...       -0.039143
# koi_impact_err1           0.014050     0.038153  ...       -0.036202
# koi_impact_err2           0.031717    -0.060192  ...        0.006070
# koi_duration             -0.272678     0.216271  ...       -0.069682
# koi_duration_err1        -0.543305     0.246869  ...       -0.084747
# koi_duration_err2         0.543305    -0.246869  ...        0.084747
# koi_depth                 0.071058    -0.051029  ...       -0.136710
# koi_depth_err1           -0.007781     0.047697  ...       -0.009071
# koi_depth_err2            0.007781    -0.047697  ...        0.009071
# koi_prad                 -0.023327     0.034992  ...       -0.020881
# koi_prad_err1            -0.017064     0.035731  ...       -0.019059
# koi_prad_err2             0.022526    -0.032594  ...        0.020586
# koi_teq                   0.233077    -0.324462  ...       -0.211109
# koi_insol                 0.011829    -0.022279  ...        0.012679
# koi_insol_err1            0.016890    -0.030213  ...       -0.005667
# koi_insol_err2           -0.011013     0.021091  ...       -0.002594
# koi_model_snr             0.081277    -0.058781  ...       -0.115150
# koi_tce_plnt_num         -0.017752     0.003827  ...        0.132981
# koi_steff                -0.034960     0.008367  ...       -0.607292
# koi_steff_err1           -0.080747     0.037650  ...       -0.824761
# koi_steff_err2            0.058992    -0.026393  ...        1.000000
# koi_slogg                 0.006293    -0.006220  ...        0.076439
# koi_slogg_err1           -0.005176    -0.032912  ...       -0.155751
# koi_slogg_err2            0.186627    -0.121174  ...        0.392455
# koi_srad                 -0.005859    -0.004924  ...        0.021225
# koi_srad_err1            -0.032526     0.010617  ...       -0.054084
# koi_srad_err2             0.002350     0.010165  ...        0.018739
# ra                        0.032093    -0.029615  ...       -0.128782
# dec                      -0.009394     0.012702  ...        0.006158
# koi_kepmag                0.025988     0.010124  ...        0.068910
#
#                    koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# kepid               0.052255       -0.026706       -0.024098 -0.027171
# koi_score           0.150017       -0.164267        0.228382 -0.071767
# koi_fpflag_nt      -0.001982       -0.001589       -0.006561  0.000393
# koi_fpflag_ss      -0.076140        0.123719       -0.043734  0.047205
# koi_fpflag_co      -0.018899       -0.007460       -0.050906  0.041572
# koi_fpflag_ec       0.002046       -0.005278       -0.036580  0.019290
# koi_period          0.001877       -0.006466       -0.003180 -0.000993
# koi_period_err1    -0.006293        0.005176       -0.186627  0.005859
# koi_period_err2     0.006293       -0.005176        0.186627 -0.005859
# koi_time0bk        -0.006220       -0.032912       -0.121174 -0.004924
# koi_time0bk_err1   -0.034973        0.032570       -0.149120  0.032212
# koi_time0bk_err2    0.034973       -0.032570        0.149120 -0.032212
# koi_impact         -0.059275        0.010622        0.000479  0.022645
# koi_impact_err1     0.006990        0.007949       -0.008021  0.005847
# koi_impact_err2     0.034500        0.017306       -0.016622 -0.018093
# koi_duration       -0.122239        0.101232       -0.090946  0.013675
# koi_duration_err1  -0.045687        0.024178       -0.160885  0.025427
# koi_duration_err2   0.045687       -0.024178        0.160885 -0.025427
# koi_depth          -0.008367        0.105980       -0.017882 -0.016826
# koi_depth_err1      0.008312       -0.006440        0.014086 -0.002443
# koi_depth_err2     -0.008312        0.006440       -0.014086  0.002443
# koi_prad           -0.097329       -0.002666        0.018033  0.056669
# koi_prad_err1      -0.095314        0.021120       -0.014114  0.044956
# koi_prad_err2       0.093790       -0.000418       -0.017074 -0.052333
# koi_teq            -0.527374        0.260926        0.000048  0.439855
# koi_insol          -0.285928        0.021664        0.027810  0.530914
# koi_insol_err1     -0.322647        0.041467        0.012328  0.508532
# koi_insol_err2      0.265902       -0.031848       -0.022637 -0.517583
# koi_model_snr      -0.045613        0.118025       -0.022571 -0.010111
# koi_tce_plnt_num    0.034286       -0.036911        0.115522  0.003936
# koi_steff          -0.139534        0.216320       -0.381651 -0.117195
# koi_steff_err1      0.065907        0.206733       -0.448838 -0.090178
# koi_steff_err2      0.076439       -0.155751        0.392455  0.021225
# koi_slogg           1.000000       -0.480194        0.024889 -0.639253
# koi_slogg_err1     -0.480194        1.000000       -0.228115  0.079555
# koi_slogg_err2      0.024889       -0.228115        1.000000  0.047322
# koi_srad           -0.639253        0.079555        0.047322  1.000000
# koi_srad_err1      -0.626469        0.202477       -0.155349  0.749843
# koi_srad_err2       0.537272       -0.168746       -0.007646 -0.873577
# ra                 -0.081565        0.085926       -0.067812  0.046028
# dec                 0.051178       -0.028740       -0.020523 -0.028442
# koi_kepmag          0.474307       -0.335159       -0.015315 -0.171584
#
#                    koi_srad_err1  koi_srad_err2        ra       dec  \
# kepid                  -0.027871       0.024720 -0.002288  0.993587
# koi_score              -0.117010       0.075529 -0.168666  0.094944
# koi_fpflag_nt           0.002640      -0.001160  0.012693  0.007914
# koi_fpflag_ss           0.051208      -0.045701  0.086374 -0.048116
# koi_fpflag_co           0.038069      -0.030926  0.159923 -0.097175
# koi_fpflag_ec           0.026828      -0.010113  0.070498 -0.045119
# koi_period             -0.000435       0.001556  0.005670  0.011479
# koi_period_err1         0.032526      -0.002350 -0.032093  0.009394
# koi_period_err2        -0.032526       0.002350  0.032093 -0.009394
# koi_time0bk             0.010617       0.010165 -0.029615  0.012702
# koi_time0bk_err1        0.055010      -0.031055 -0.013485 -0.003040
# koi_time0bk_err2       -0.055010       0.031055  0.013485  0.003040
# koi_impact              0.021761      -0.029131  0.022464 -0.001804
# koi_impact_err1         0.003378      -0.006546  0.025825 -0.032158
# koi_impact_err2        -0.007532       0.023282  0.004103 -0.004721
# koi_duration            0.049342      -0.017941  0.030927 -0.028101
# koi_duration_err1       0.061000      -0.032211  0.002820 -0.016106
# koi_duration_err2      -0.061000       0.032211 -0.002820  0.016106
# koi_depth              -0.004058       0.002430  0.028545 -0.018076
# koi_depth_err1          0.000357       0.001901  0.011379 -0.015920
# koi_depth_err2         -0.000357      -0.001901 -0.011379  0.015920
# koi_prad                0.035655      -0.060269  0.008716  0.003037
# koi_prad_err1           0.060530      -0.046583  0.011950  0.005016
# koi_prad_err2          -0.031048       0.060407 -0.009291 -0.003291
# koi_teq                 0.410367      -0.392145  0.119479 -0.059060
# koi_insol               0.345117      -0.457036  0.026666 -0.013950
# koi_insol_err1          0.478917      -0.414967  0.027288 -0.012333
# koi_insol_err2         -0.332329       0.513084 -0.027574  0.014541
# koi_model_snr           0.001225      -0.002204  0.038810 -0.001677
# koi_tce_plnt_num       -0.013439      -0.022958 -0.039501  0.022664
# koi_steff              -0.042409       0.074115  0.107079 -0.025601
# koi_steff_err1          0.011252       0.046087  0.139307 -0.009717
# koi_steff_err2         -0.054084       0.018739 -0.128782  0.006158
# koi_slogg              -0.626469       0.537272 -0.081565  0.051178
# koi_slogg_err1          0.202477      -0.168746  0.085926 -0.028740
# koi_slogg_err2         -0.155349      -0.007646 -0.067812 -0.020523
# koi_srad                0.749843      -0.873577  0.046028 -0.028442
# koi_srad_err1           1.000000      -0.653038  0.058097 -0.029042
# koi_srad_err2          -0.653038       1.000000 -0.050524  0.025699
# ra                      0.058097      -0.050524  1.000000 -0.014373
# dec                    -0.029042       0.025699 -0.014373  1.000000
# koi_kepmag             -0.203892       0.156820  0.005597  0.015997
#
#                    koi_kepmag
# kepid                0.017525
# koi_score            0.042112
# koi_fpflag_nt       -0.003753
# koi_fpflag_ss        0.000628
# koi_fpflag_co        0.060592
# koi_fpflag_ec        0.039075
# koi_period          -0.009858
# koi_period_err1     -0.025988
# koi_period_err2      0.025988
# koi_time0bk          0.010124
# koi_time0bk_err1    -0.040635
# koi_time0bk_err2     0.040635
# koi_impact          -0.009796
# koi_impact_err1      0.050631
# koi_impact_err2      0.001892
# koi_duration        -0.098477
# koi_duration_err1   -0.061397
# koi_duration_err2    0.061397
# koi_depth            0.042719
# koi_depth_err1       0.016809
# koi_depth_err2      -0.016809
# koi_prad            -0.022565
# koi_prad_err1       -0.014782
# koi_prad_err2        0.022804
# koi_teq             -0.257340
# koi_insol           -0.069748
# koi_insol_err1      -0.092285
# koi_insol_err2       0.068695
# koi_model_snr       -0.114525
# koi_tce_plnt_num    -0.053189
# koi_steff           -0.333394
# koi_steff_err1       0.061416
# koi_steff_err2       0.068910
# koi_slogg            0.474307
# koi_slogg_err1      -0.335159
# koi_slogg_err2      -0.015315
# koi_srad            -0.171584
# koi_srad_err1       -0.203892
# koi_srad_err2        0.156820
# ra                   0.005597
# dec                  0.015997
# koi_kepmag           1.000000
#
# [42 rows x 42 columns]

# %% [markdown]
# ## 4. Resultados de referencia con un modelo simple (regresión lineal) aplicando un preproceso de los datos

# %% [markdown]
# ### Preprocesado básico

# %%
def imputar_valores(data, replace_dict = None):
    col_mask = data.isna().sum() > 0
    null_cols = data.columns[col_mask]
    if replace_dict is None:
        replace_dict = {}
        data_clean = data.dropna(axis = 0)
        for col in null_cols:
            if col.endswith(("_err1", "_err2")):
                suffix = "_err1" if col.endswith("_err1") else "_err2"
                p_col = col.removesuffix(suffix)
                replace_dict[col] = (data_clean[col]/data_clean[p_col]).mean()
                if not np.isfinite(replace_dict[col]):
                    replace_dict[col] = 0
            else:
                if data[col].dtype.name == "string":
                    data[col] = "placeholder"
                else:
                    replace_dict[col] = data[col].mean()
                  
    return data.fillna(replace_dict), replace_dict

# %%
directly_related = ["koi_pdisposition", "koi_score", "kepler_name", "koi_fpflag_nt", "koi_fpflag_ss", "koi_fpflag_co", "koi_fpflag_ec", "koi_tce_delivname"]
exo = exo.drop(columns = directly_related)

# Dividir en Test/Train
target_column = "koi_disposition"

train_set, test_set = train_test_split(exo, test_size = 0.3, random_state = 42)

x_train = train_set.drop(columns = target_column)
x_test = test_set.drop(columns=target_column)
y_train = train_set[target_column]
y_test = test_set[target_column]

# Imputación missing values
x_train, replace_dict = imputar_valores(x_train)
x_test, _ = imputar_valores(x_test, replace_dict)

# Codificación variables categóricas
x_train = pd.get_dummies(x_train, drop_first = True)
x_test = pd.get_dummies(x_test, drop_first = True)

# Alineamos columnas entre train y test
x_test = x_test.reindex(columns = x_train.columns, fill_value = 0)

# Normalización de variables
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# Codificación variable objetivo
le = LabelEncoder()
y_train_enc = le.fit_transform(y_train)
y_test_enc  = le.transform(y_test)

# Modelo simple: regresión logística
model = LogisticRegression(max_iter = 1000)
model.fit(x_train_scaled, y_train_enc)
y_pred = model.predict(x_test_scaled)

# Resultados
print("Accuracy:", accuracy_score(y_test_enc, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test_enc, y_pred))
print("Classification Report:\n", classification_report(y_test_enc, y_pred))
# Out:
# Accuracy: 0.5721254355400697
# Confusion Matrix:
#  [[   7  184  538]
#  [   0  350  370]
#  [   3  133 1285]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.70      0.01      0.02       729
#            1       0.52      0.49      0.50       720
#            2       0.59      0.90      0.71      1421
#
#     accuracy                           0.57      2870
#    macro avg       0.60      0.47      0.41      2870
# weighted avg       0.60      0.57      0.48      2870
